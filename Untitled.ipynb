# %%
import pandas as pd
import json5 as js
from fil import EasyDF

# %%
with open("dati-json/dpc-covid19-ita-regioni.json") as file:
    regioni_raw = js.load(file)

regioni_all = pd.DataFrame.from_dict(regioni_raw)
regioni_filtered = regioni_all.drop(columns=['stato', 'codice_regione', 'lat', 'long'])

# %%
regioni = EasyDF(regioni_filtered)

# %%
regioni.plot('totale_casi', ['Veneto','Lombardia','Emilia Romagna'],'tamponi');

# %%
regioni.plot('deceduti', ['Veneto','Lombardia','Emilia Romagna'],'totale_casi');

# %%
regioni.plot('totale_ospedalizzati', ['Veneto','Lombardia','Emilia Romagna'],'totale_casi');

# %%
regioni.plot('deceduti', ['Veneto','Lombardia','Emilia Romagna'],'totale_ospedalizzati');

# %%
regioni.columns
# Out:
# Index(['data', 'denominazione_regione', 'ricoverati_con_sintomi',
#        'terapia_intensiva', 'totale_ospedalizzati', 'isolamento_domiciliare',
#        'totale_attualmente_positivi', 'nuovi_attualmente_positivi',
#        'dimessi_guariti', 'deceduti', 'totale_casi', 'tamponi'],
#       dtype='object')

# %%
regioni.plot('terapia_intensiva', ['Veneto','Lombardia','Emilia Romagna'],'totale_ospedalizzati');

# %%
regioni.plot('deceduti', ['Veneto','Lombardia','Emilia Romagna'], 'totale_casi');
